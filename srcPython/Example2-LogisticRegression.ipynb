# %% [markdown]
# # Unit3-Example2 Use of Logistic Regression classification model
# ## Subject: Machine Learning - MSc. Computational Biology
# Author: Esteban García-Cuesta, Departamento de Inteligencia Artificial, UPM (License CC-BY-NC)
#
# This code has been developed to be used exclusively for educational purposes.
#
# ## Objectives:
#   - Learn how the Logistic Regression model works
#   - Learn what is the purpose of regularization in ML models
#   - Learn how to apply logistic regression
#
# ## TO-DO at home
#   1. Add the needed changes to perform CV and return the best classifier and its test classification error.

# %%
print(__doc__)

# Code source: Esteban García Cuesta
# License: CC-BY-NC

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import numpy as np

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :4]
Y = iris.target

# Create an instance of Logistic Regression Classifier and fit the data.
logreg = LogisticRegression(C=1, max_iter=1000 )
logreg.fit(X, Y)

yhatTrain = logreg.predict(X)

print('Training classification error: ' + str(np.mean(yhatTrain != Y)))
# Out:
# Automatically created module for IPython interactive environment
# Training classification error: 0.02666666666666667
